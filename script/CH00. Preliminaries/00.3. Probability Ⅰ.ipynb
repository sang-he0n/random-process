# %% [markdown]
# # CH00.3. **Probability Ⅰ**

# %% [markdown]
# > ## **확률론(Probability theory)**

# %% [markdown]
# #### **(1) 정의** : 확률의 무작위적 현상을 수학적으로 모델링하는 방법

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **확률 실험(Probabilistic experiment)**

# %% [markdown]
# #### **(1) 무작위 실험(Random Experiments)** : 동일한 조건에서 반복하더라도 결과를 확실하게 예측할 수 없는 실험

# %% [markdown]
# #### **(2) 시행(Trial)** : 무작위 실험을 한 번 수행하는 행위

# %% [markdown]
# #### **(3) 결과(Outcome)** : 시행을 했을 때 실제로 관찰되는 단일한 결과

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **표본 공간(Sample space; $ \Omega{} $)**

# %% [markdown]
# #### **(1) 정의** : 가능한 모든 결과들의 집합
# #### $ \Leftrightarrow{} \Omega{} := \{ \text{outcome}_{1}, \text{outcome}_{2}, \cdots{} \} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **사건(Evenet)**

# %% [markdown]
# #### **(1) 정의** : 표본 공간에 대응되는 시그마-공간 $ \mathcal{F} $의 원소
# #### $ \Leftrightarrow{} A \in{} \mathcal{F} \;\; \text{ where } \, \mathcal{F} \subseteq 2^{\Omega{}}, \;\; \Omega{} : \text{sample space} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **확률 측도(Probability measure)**

# %% [markdown]
# #### **(1) 정의** : 어떠한 표본 공간의 시그마-공간 $ \mathcal{F} $을 $ 0 $과 $ 1 $ 사이를 매핑하며 표본 공간을 $ 1 $로 정규화하는 반환하는 집합 함수
# #### $ \Leftrightarrow{} P : \mathcal{F} \rightarrow{} [0, 1] $

# %% [markdown]
# #### **(2) 공리** : 어떠한 시그마-공간 $ \mathcal{F} $에 대응되는 측도 $ P $가 존재할 때 아래를 만족해야함
# ##### $ \hspace{0.15cm} $ ① $ P(A) \geq{} 0 \;\; \forall{} \, A \in{} \mathcal{F} $
# ##### $ \hspace{0.15cm} $ ② $ P(\empty{}) = 0 $
# ##### $ \hspace{0.15cm} $ ③ $ P(\Omega{}) = 1 $
# ##### $ \hspace{0.15cm} $ ④ $ \displaystyle{} P(\cup^{\infty{}}_{i=1}A_{i}) = \sum^{\infty{}}_{i=1} P(A_{i}) \;\; \text{ s.t. } \, A_{i} \cap{} A_{j} = \empty{} $

# %% [markdown]
# #### **(3) 성질** : 어떠한 시그마-공간 $ \mathcal{F} $에 대응되는 측도 $ P $가 존재할 때 아래를 만족함
# ##### $ \hspace{0.15cm} $ ① $ A \subseteq{} B \; \Rightarrow{} \; P(A) \leq{} P(B) $
# ##### $ \hspace{0.15cm} $ ② $ P(A) + P(A^{c}) = 1 $
# ##### $ \hspace{0.15cm} $ ③ $ P(A\cup{}B) = P(A) + P(B) - P(A\cap{}B) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **확률 공간(Probability space)**

# %% [markdown]
# #### **(1) 정의** : 표본 공간과 이에 대응되는 시그마-공간, 확률 측도로 구성된 객체
# #### $ \Leftrightarrow{} (\Omega{}, \mathcal{F}, P) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **독립(Independence)**

# %% [markdown]
# #### **(1) 정의** : 어떠한 사건의 확률이 다른 사건의 확률에 영향을 미치지 않는 관계
# #### $ \Leftrightarrow{} P(A\cap{}B) = P(A)P(B) \;\; \text{ where } \, A, B \in{} \mathcal{F} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Theorem 0-6)** Mutually independence

# %% [markdown]
# #### 어떠한 사건 $ A, B, C $가 존재할 때 해당 사건들의 아래 두 조건을 만족해야지 상호(mutually) 독립 관계임을 정의한다.
# #### $ \Leftrightarrow{} \left.{} \begin{array}{l} P(A\cap{}B) = P(A)P(B) \\ \\ P(A\cap{}C) = P(A)P(C) \\ \\ P(C\cap{}B) = P(C)P(B) \end{array} \right\}{} \;\; \cdots{} \; \text{pairwise independence} $
# #### $ \hspace{0.675cm} P(A\cap{}B\cap{}C) = P(A)P(B)P(C) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **조건부 확률(Conditional probability)**

# %% [markdown]
# #### **(1) 정의** : 어떠한 사건이 이미 발생했다고 가정할 때 다른 사건이 일어날 확률
# #### $ \Leftrightarrow{} P(A|B) = \frac{P(A\cap{}B)}{P(B)} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **베이즈 정리(Bayes's rule)**

# %% [markdown]
# #### **(1) 정의** : 어떤 사건 $ 𝐵 $가 발생한다고 가정했을 때, 그 원인으로 사건 $ A $가 일어났을 가능성을 계산하는 정리
# #### $ \Leftrightarrow{} P(A|B) = \frac{P(B|A)P(A)}{P(B)} $

# %% [markdown]
# #### **(2) 구성** :
# ##### $ \hspace{0.15cm} $ ① $ P(A|B) $ : posterior, **[~]**
# ##### $ \hspace{0.15cm} $ ② $ P(B|A) $ : likeli-hood, **[~]**
# ##### $ \hspace{0.15cm} $ ③ $ P(A) $ : prior, **[~]**
# ##### $ \hspace{0.15cm} $ ④ $ P(B) $ : evidence, **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Theorem 0-7)** Expaned form of bayes's rule

# %% [markdown]
# #### 표본 공간을 분할(partitioned)하는 사건 $ A_{i} $가 존재할 때 $ B $에 대한 $ A_{i} $의 베이즈 정리는 다음과 같이 정의된다.
# #### $ \Leftrightarrow{} P(A_{i}|B) = \frac{P(B|A_{i})P(A_{i})}{\sum_{j}P(B|A_{j})P(A_{j})} \;\; \text{ s.t. } \, \Omega{} = \cup_{j}A_{j}, \;\; A_{i} \cap{} A_{j} = \empty{} $
